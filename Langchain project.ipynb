# %%
from dotenv import load_dotenv
import os

from langchain.prompts.prompt import PromptTemplate
from langchain_openai import ChatOpenAI
from langchain.chains import LLMChain

if __name__ == "__main__":
    load_dotenv()

    information='''Elon Reeve Musk (/ˈiːlɒn/ EE-lon; born June 28, 1971) is a businessman and investor. He is the founder, chairman, CEO, and CTO of SpaceX; angel investor, CEO, product architect, and former chairman of Tesla, Inc.; owner, executive chairman, and CTO of X Corp.; founder of the Boring Company and xAI; co-founder of Neuralink and OpenAI; and president of the Musk Foundation. He is one of the wealthiest people in the world; as of April 2024, Forbes estimates his net worth to be $178 billion.[4]

A member of the wealthy South African Musk family, Musk was born in Pretoria and briefly attended the University of Pretoria before immigrating to Canada at age 18, acquiring citizenship through his Canadian-born mother. Two years later, he matriculated at Queen's University at Kingston in Canada. Musk later transferred to the University of Pennsylvania and received bachelor's degrees in economics and physics. He moved to California in 1995 to attend Stanford University, but dropped out after two days and, with his brother Kimbal, co-founded online city guide software company Zip2. The startup was acquired by Compaq for $307 million in 1999. That same year, Musk co-founded X.com, a direct bank. X.com merged with Confinity in 2000 to form PayPal. In October 2002, eBay acquired PayPal for $1.5 billion. Using $100 million of the money he made from the sale of PayPal, Musk founded SpaceX, a spaceflight services company, in 2002.

In 2004, Musk became an early investor in electric vehicle manufacturer Tesla Motors, Inc. (later Tesla, Inc.). He became the company's chairman and product architect, assuming the position of CEO in 2008. In 2006, Musk helped create SolarCity, a solar-energy company that was acquired by Tesla in 2016 and became Tesla Energy. In 2013, he proposed a hyperloop high-speed vactrain transportation system. In 2015, he co-founded OpenAI, a nonprofit artificial intelligence research company. The following year, Musk co-founded Neuralink—a neurotechnology company developing brain–computer interfaces—and the Boring Company, a tunnel construction company. In 2018, the U.S. Securities and Exchange Commission (SEC) sued Musk, alleging that he had falsely announced that he had secured funding for a private takeover of Tesla. To settle the case, Musk stepped down as the chairman of Tesla and paid a $20 million fine. In 2022, he acquired Twitter for $44 billion. He subsequently merged the company into newly created X Corp. and rebranded the service as X the following year. In March 2023, Musk founded xAI, an artificial intelligence company.

Musk has expressed views that have made him a polarizing figure.[5] He has been criticized for making unscientific and misleading statements, including COVID-19 misinformation and antisemitic conspiracy theories.[5][6][7][8] His ownership of Twitter has been similarly controversial, being marked by layoffs of large numbers of employees, an increase in hate speech and misinformation and disinformation on the website, and changes to Twitter Blue verification.'''
    summary_template = """
    given the information {information} about a person I want you to create:
    1. A short summary of the person
    2. Two interesting fact about the person"""

    summary_prompt_template = PromptTemplate(
        input_variables=["information"], template=summary_template
    )

    llm = ChatOpenAI(temperature=0.6, model_name="gpt-3.5-turbo")

    chain = summary_prompt_template | llm
    res = chain.invoke(input={"information":information})
    print(res)
# Out:
# content='1. Elon Musk is a South African-born businessman and investor known for his roles in various companies such as SpaceX, Tesla, Neuralink, and the Boring Company. He is one of the wealthiest individuals in the world with a net worth estimated to be $178 billion.\n\n2. Elon Musk dropped out of Stanford University after just two days to pursue entrepreneurial ventures. He has been involved in the founding of multiple successful companies, including PayPal, Tesla Motors, and SolarCity. Musk is also known for his controversial statements and views on various topics.' response_metadata={'token_usage': {'completion_tokens': 109, 'prompt_tokens': 718, 'total_tokens': 827}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None} id='run-b7bd0c8a-b50d-4bfd-a233-4e2bc6f0243b-0'

# %%
def scrape_linkedin_profile(linkedin_profile_url:str,mock:bool=False):
    """scrape information from LinkedIn profiles,
    Manually scrape the information from the LinkedIn profile"""
    
    if mock:
        linkedin_profile_url='https://gist.githubusercontent.com/emarco177/0d6a3f93dd06634d95e46a2782ed7490/raw/fad4d7a87e3e934ad52ba2a968bad9eb45128665/eden-marco.json'
        response=requests.get(linkedin_profile_url,timeout=10)
    else:
        api_key = 'MEDJdC4YHw91FB6JN_bpnQ'
    headers = {'Authorization': 'Bearer ' + api_key}
    api_endpoint = 'https://nubela.co/proxycurl/api/linkedin/company/resolve'
    params = {
        'company_domain': 'accenture.com',
        'company_name': 'Accenture',
        'company_location': 'sg',
        'enrich_profile': 'enrich',
    }
    response = requests.get(api_endpoint,
                            params=params,
                            headers=headers)

# %%
import requests

api_key = 'MEDJdC4YHw91FB6JN_bpnQ'
headers = {'Authorization': 'Bearer ' + api_key}
api_endpoint = 'https://nubela.co/proxycurl/api/linkedin/company/resolve'
params = {
    'company_domain': 'accenture.com',
    'company_name': 'Accenture',
    'company_location': 'sg',
    'enrich_profile': 'enrich',
}
response = requests.get(api_endpoint,
                        params=params,
                        headers=headers)

# %%
response.json()
# Out:
# {'url': 'https://www.linkedin.com/company/accenture',
#  'profile': {'linkedin_internal_id': '1033',
#   'description': 'Accenture is a leading global professional services company that helps the world’s leading businesses, governments and other organizations build their digital core, optimize their operations, accelerate revenue growth and enhance citizen services—creating tangible value at speed and scale.We are a talent and innovation-led company serving clients in more than 120 countries. Technology is at the core of change today, and we are one of the world’s leaders in helping drive that change, with strong ecosystem relationships. We combine our strength in technology and leadership in cloud, data and AI with unmatched industry experience, functional expertise and global delivery capability. We are uniquely able to deliver tangible outcomes because of our broad range of services, solutions and assets across Strategy & Consulting, Technology, Operations, Industry X and Song.These capabilities, together with our culture of shared success and commitment to creating 360° value, enable us to help our clients reinvent and build trusted, lasting relationships. We measure our success by the 360° value we create for our clients, each other, our shareholders, partners and communities.',
#   'website': 'http://www.accenture.com',
#   'industry': 'Business Consulting and Services',
#   'company_size': [10001, None],
#   'company_size_on_linkedin': 574817,
#   'hq': {'country': 'IE',
#    'city': 'Dublin 2',
#    'postal_code': None,
#    'line_1': 'Grand Canal Harbour',
#    'is_hq': True,
#    'state': None},
#   'company_type': 'PUBLIC_COMPANY',
#   'founded_year': None,
#   'specialities': ['Management Consulting',
#    'Systems Integration and Technology',
#    'Business Process Outsourcing',
#    'Application and Infrastructure Outsourcing'],
#   'locations': [{'country': 'IE',
#     'city': 'Dublin 2',
#     'postal_code': None,
#     'line_1': 'Grand Canal Harbour',
#     'is_hq': True,
#     'state': None},
#    {'country': 'US',
#     'city': 'San Francisco',
#     'postal_code': '94105',
#     'line_1': '415 Mission Street',
#     'is_hq': False,
#     'state': 'California'},
#    {'country': 'FI',
#     'city': 'Helsinki',
#     'postal_code': '00180',
#     'line_1': 'Porkkalankatu 5',
#     'is_hq': False,
#     'state': 'Southern Finland'},
#    {'country': 'MY',
#     'city': 'Kuala Lumpur',
#     'postal_code': '55188',
#     'line_1': 'Level 29 & 30, Menara Exchange 106',
#     'is_hq': False,
#     'state': 'Kuala Lumpur'},
#    {'country': 'PL',
#     'city': 'Warsaw',
#     'postal_code': '00-121',
#     'line_1': 'Warsaw Towers Sienna 39',
#     'is_hq': False,
#     'state': None},
#    {'country': 'US',
#     'city': 'Washington',
#     'postal_code': '20006',
#     'line_1': '800 Connecticut Ave NW',
#     'is_hq': False,
#     'state': 'District of Columbia'},
#    {'country': 'NO',
#     'city': 'Fornebu',
#     'postal_code': '1326',
#     'line_1': 'Rolfsbuktveien 2, 1364',
#     'is_hq': False,
#     'state': None},
#    {'country': 'BR',
#     'city': 'Sao Paulo',
#     'postal_code': '04717-004',
#     'line_1': 'Rua Alexandre Dumas, 2051',
#     'is_hq': False,
#     'state': 'São Paulo'},
#    {'country': 'IE',
#     'city': 'Dublin',
#     'postal_code': 'D02 P820',
#     'line_1': '1 Grand Canal Square',
#     'is_hq': False,
#     'state': 'Dublin'},
#    {'country': 'BR',
#     'city': 'Recife',
#     'postal_code': '50030-230',
#     'line_1': 'Edifício Vasco Rodrigues Rua Cais Do Apolo, 222 - 10º Andar - Recife',
#     'is_hq': False,
#     'state': 'Pernambuco'},
#    {'country': 'IN',
#     'city': 'Mumbai',
#     'postal_code': '400708',
#     'line_1': '1st, 2nd, 3rd, & 4th Office Level, Building No. 02',
#     'is_hq': False,
#     'state': 'Maharashtra'},
#    {'country': 'US',
#     'city': 'Austin',
#     'postal_code': '78701',
#     'line_1': '323 Congress Avenue',
#     'is_hq': False,
#     'state': 'Texas'},
#    {'country': 'PH',
#     'city': 'Muntinlupa',
#     'postal_code': '1781',
#     'line_1': 'Axis Tower One',
#     'is_hq': False,
#     'state': 'Metro Manila'},
#    {'country': 'PH',
#     'city': 'Cebu City',
#     'postal_code': '6000',
#     'line_1': 'W Geonzon St.',
#     'is_hq': False,
#     'state': 'Cebu'},
#    {'country': 'PH',
#     'city': 'Cebu City',
#     'postal_code': '6000',
#     'line_1': 'Don Gil Garcia Street',
#     'is_hq': False,
#     'state': 'Cebu'},
#    {'country': 'PH',
#     'city': 'Cebu City',
#     'postal_code': '6000',
#     'line_1': 'Cardinal Rosales Ave.',
#     'is_hq': False,
#     'state': 'Cebu'},
#    {'country': 'PH',
#     'city': 'Cebu City',
#     'postal_code': '6000',
#     'line_1': 'W Geonzon St.',
#     'is_hq': False,
#     'state': 'Cebu'},
#    {'country': 'US',
#     'city': 'Austin',
#     'postal_code': '78704',
#     'line_1': '3601 S. Congress Avenue Suite B100',
#     'is_hq': False,
#     'state': 'Texas'},
#    {'country': 'US',
#     'city': 'Irving',
#     'postal_code': '75039',
#     'line_1': "5205 North O'Connor Boulevard",
#     'is_hq': False,
#     'state': 'Texas'},
#    {'country': 'US',
#     'city': 'Houston',
#     'postal_code': '77002',
#     'line_1': '1301 Fannin St.',
#     'is_hq': False,
#     'state': 'Texas'},
#    {'country': 'US',
#     'city': 'San Antonio',
#     'postal_code': '78249',
#     'line_1': '6415 Babcock Road',
#     'is_hq': False,
#     'state': 'Texas'},
#    {'country': 'US',
#     'city': 'San Antonio',
#     'postal_code': '78238',
#     'line_1': '7050 Fairgrounds Parkway',
#     'is_hq': False,
#     'state': 'Texas'},
#    {'country': 'US',
#     'city': 'San Jose',
#     'postal_code': '95113',
#     'line_1': '50 West San Fernando Street',
#     'is_hq': False,
#     'state': 'California'},
#    {'country': 'FI',
#     'city': 'Helsinki',
#     'postal_code': '00100',
#     'line_1': 'Aleksanterinkatu 46 A, Floor 4',
#     'is_hq': False,
#     'state': None},
#    {'country': 'FI',
#     'city': 'Tampere',
#     'postal_code': '33720',
#     'line_1': 'Hermiankatu 3',
#     'is_hq': False,
#     'state': None},
#    {'country': 'PH',
#     'city': 'San Nicolas',
#     'postal_code': '2901',
#     'line_1': 'No. 1 San Francisco',
#     'is_hq': False,
#     'state': 'Ilocos Norte'},
#    {'country': 'PH',
#     'city': 'Mandaluyong',
#     'postal_code': '1554',
#     'line_1': 'EDSA cor. Pioneer Street',
#     'is_hq': False,
#     'state': 'Metro Manila'},
#    {'country': 'PH',
#     'city': 'Taguig',
#     'postal_code': '1634',
#     'line_1': '19/F Uptown Tower 3, 11th Avenue, Bonifacio Global City',
#     'is_hq': False,
#     'state': 'Metro Manila'},
#    {'country': 'PH',
#     'city': 'Quezon City',
#     'postal_code': '1109',
#     'line_1': 'General Roxas Avenue and General Aguinaldo Avenue',
#     'is_hq': False,
#     'state': 'Metro Manila'},
#    {'country': 'US',
#     'city': 'San Francisco',
#     'postal_code': '94105',
#     'line_1': '415 Mission Street',
#     'is_hq': False,
#     'state': 'California'},
#    {'country': 'MY',
#     'city': 'Kuala Lumpur',
#     'postal_code': '59200',
#     'line_1': 'Level 15 & 16,  Vertical Tower B Avenue 10,  The Vertical',
#     'is_hq': False,
#     'state': 'Kuala Lumpur'},
#    {'country': 'MY',
#     'city': 'Kuala Lumpur',
#     'postal_code': '59200',
#     'line_1': 'Level 20 & 21,  Vertical Tower B Avenue 10  The Vertical',
#     'is_hq': False,
#     'state': 'Kuala Lumpur'},
#    {'country': 'MY',
#     'city': 'Kuala Lumpur',
#     'postal_code': '59200',
#     'line_1': 'Level 11, UOA Corporate Tower, Avenue 10',
#     'is_hq': False,
#     'state': 'Kuala Lumpur'},
#    {'country': 'MY',
#     'city': 'Petaling Jaya',
#     'postal_code': '47301',
#     'line_1': 'Suite 2.09(A), Block E, Level 1, Kelana Parkview Tower',
#     'is_hq': False,
#     'state': 'Selangor'},
#    {'country': 'MY',
#     'city': 'Kuching',
#     'postal_code': '93450',
#     'line_1': 'Suite 107, 1st Floor Crown Towers',
#     'is_hq': False,
#     'state': 'Sarawak'},
#    {'country': 'MY',
#     'city': 'Selangor',
#     'postal_code': '47500',
#     'line_1': 'Level 17,  Sunway GEO Tower Persiaran Lagoon Selatan',
#     'is_hq': False,
#     'state': 'Subang Jaya'},
#    {'country': 'MY',
#     'city': 'Selangor',
#     'postal_code': '47500',
#     'line_1': 'Level 9,  The Pinnacle Persiaran Lagoon Selatan',
#     'is_hq': False,
#     'state': 'Subang Jaya'},
#    {'country': 'MY',
#     'city': 'Petaling Jaya',
#     'postal_code': '46200',
#     'line_1': 'No 1, Jalan Kemajuan Seksyen 13',
#     'is_hq': False,
#     'state': 'Selangor'},
#    {'country': 'US',
#     'city': 'Bentonville',
#     'postal_code': '72712',
#     'line_1': '805 South Walton Suite',
#     'is_hq': False,
#     'state': 'Arkansas'},
#    {'country': 'US',
#     'city': 'Phoenix',
#     'postal_code': '85003',
#     'line_1': '101 North 1st Avenue',
#     'is_hq': False,
#     'state': 'Arizona'},
#    {'country': 'US',
#     'city': 'Washington',
#     'postal_code': '20005',
#     'line_1': '1201 New York Avenue Northwest',
#     'is_hq': False,
#     'state': 'District of Columbia'},
#    {'country': 'US',
#     'city': 'Albany',
#     'postal_code': '12207',
#     'line_1': '54 State St.',
#     'is_hq': False,
#     'state': 'New York'},
#    {'country': 'US',
#     'city': 'New York',
#     'postal_code': '12553',
#     'line_1': '155 Avenue of Americas',
#     'is_hq': False,
#     'state': 'New York'},
#    {'country': 'US',
#     'city': 'New York',
#     'postal_code': '10001',
#     'line_1': '395 9th Avenue',
#     'is_hq': False,
#     'state': 'New York'},
#    {'country': 'US',
#     'city': 'Irvine',
#     'postal_code': '92618',
#     'line_1': '300 Spectrum Center Drive',
#     'is_hq': False,
#     'state': 'California'},
#    {'country': 'US',
#     'city': 'Los Angeles',
#     'postal_code': '90013',
#     'line_1': '1003 E. 4th Place',
#     'is_hq': False,
#     'state': 'California'},
#    {'country': 'US',
#     'city': 'Rancho Cordova',
#     'postal_code': '95670',
#     'line_1': '3343 Capital Center Drive',
#     'is_hq': False,
#     'state': 'California'},
#    {'country': 'US',
#     'city': 'Sacramento',
#     'postal_code': '95811',
#     'line_1': '1610 R Street',
#     'is_hq': False,
#     'state': 'California'},
#    {'country': 'US',
#     'city': 'San Diego',
#     'postal_code': '92108',
#     'line_1': '1615 Murray Canyon Road',
#     'is_hq': False,
#     'state': 'California'},
#    {'country': 'US',
#     'city': 'Denver',
#     'postal_code': '80202',
#     'line_1': '1400 16th Street',
#     'is_hq': False,
#     'state': 'Colorado'},
#    {'country': 'US',
#     'city': 'Hartford',
#     'postal_code': '6103',
#     'line_1': '755 Main Street',
#     'is_hq': False,
#     'state': 'Connecticut'},
#    {'country': 'US',
#     'city': 'Miami',
#     'postal_code': '33126',
#     'line_1': '5201 Blue Lagoon Drive',
#     'is_hq': False,
#     'state': 'Florida'},
#    {'country': 'US',
#     'city': 'Orlando',
#     'postal_code': '32819',
#     'line_1': '9400 Southpark Center Loop',
#     'is_hq': False,
#     'state': 'Florida'},
#    {'country': 'US',
#     'city': 'Tallahassee',
#     'postal_code': '32311',
#     'line_1': '3800 Esplanade Way',
#     'is_hq': False,
#     'state': 'Florida'},
#    {'country': 'US',
#     'city': 'St. Petersburg',
#     'postal_code': '33716',
#     'line_1': '140 Fountain Parkway',
#     'is_hq': False,
#     'state': 'Florida'},
#    {'country': 'PL',
#     'city': 'Katowice',
#     'postal_code': '40-101',
#     'line_1': 'Silesia Bussines Park, Chorzowska 148',
#     'is_hq': False,
#     'state': None},
#    {'country': 'PL',
#     'city': 'Krakow',
#     'postal_code': '31-154',
#     'line_1': '21 Pawia Street',
#     'is_hq': False,
#     'state': None},
#    {'country': 'PL',
#     'city': 'Lodz',
#     'postal_code': '90-530',
#     'line_1': 'University Business Park Wólczańska 178',
#     'is_hq': False,
#     'state': None},
#    {'country': 'PL',
#     'city': 'Warszawa',
#     'postal_code': '01-208',
#     'line_1': 'Przyokopowa 26',
#     'is_hq': False,
#     'state': None},
#    {'country': 'PL',
#     'city': 'Warszawa',
#     'postal_code': '00-844',
#     'line_1': 'Grzybowska 60 St',
#     'is_hq': False,
#     'state': None},
#    {'country': 'PL',
#     'city': 'Wrocław',
#     'postal_code': '54-429',
#     'line_1': 'Strzegomska 142a',
#     'is_hq': False,
#     'state': 'Dolnośląskie'},
#    {'country': 'US',
#     'city': 'Atlanta',
#     'postal_code': '30303',
#     'line_1': '100 Peachtree Street NW',
#     'is_hq': False,
#     'state': 'Georgia'},
#    {'country': 'US',
#     'city': 'Atlanta',
#     'postal_code': '30308',
#     'line_1': '75 5th Street NW',
#     'is_hq': False,
#     'state': 'Georgia'},
#    {'country': 'US',
#     'city': 'Oklahoma City',
#     'postal_code': '73102',
#     'line_1': '100 N. Broadway Avenue',
#     'is_hq': False,
#     'state': 'Oklahoma'},
#    {'country': 'US',
#     'city': 'Beaverton',
#     'postal_code': '97006',
#     'line_1': '1925 NW AmberGlen Parkway',
#     'is_hq': False,
#     'state': 'Oregon'},
#    {'country': 'US',
#     'city': 'Boise',
#     'postal_code': '83702',
#     'line_1': '913 W. River Street',
#     'is_hq': False,
#     'state': 'Idaho'},
#    {'country': 'US',
#     'city': 'Florham Park',
#     'postal_code': '7932',
#     'line_1': '500 Campus Drive',
#     'is_hq': False,
#     'state': 'New Jersey'},
#    {'country': 'AT',
#     'city': 'Vienna',
#     'postal_code': '1010',
#     'line_1': 'Börsegebäude, Schottenring 16',
#     'is_hq': False,
#     'state': None},
#    {'country': 'IN',
#     'city': 'Mumbai',
#     'postal_code': '400079',
#     'line_1': 'Plant 3, Godrej & Boyce Complex',
#     'is_hq': False,
#     'state': 'Maharashtra'},
#    {'country': 'AR',
#     'city': 'La Plata',
#     'postal_code': 'B1900CCN',
#     'line_1': 'Diagonal 80 942, La Plata. Bs As.',
#     'is_hq': False,
#     'state': 'Buenos Aires'},
#    {'country': 'FR',
#     'city': 'Toulouse',
#     'postal_code': '31700',
#     'line_1': 'Cap Constellation',
#     'is_hq': False,
#     'state': 'Blagnac'},
#    {'country': 'ID',
#     'city': 'Jakarta',
#     'postal_code': '10220',
#     'line_1': 'Wisma 46 Kota BNI-18th Floor',
#     'is_hq': False,
#     'state': 'DKI Jakarta'},
#    {'country': 'AR',
#     'city': 'Buenos Aires',
#     'postal_code': '1605',
#     'line_1': 'Bouchard 4191',
#     'is_hq': False,
#     'state': 'Buenos Aires'},
#    {'country': 'AR',
#     'city': 'Buenos Aires',
#     'postal_code': 'C1242AAT',
#     'line_1': '24 de Noviembre 2120',
#     'is_hq': False,
#     'state': 'Ciudad Autónoma de Buenos Aires'},
#    {'country': 'AR',
#     'city': 'Buenos Aires',
#     'postal_code': 'B7602',
#     'line_1': 'Av. Independencia 4250, Mar del Plata',
#     'is_hq': False,
#     'state': 'Ciudad Autónoma de Buenos Aires'},
#    {'country': 'NO',
#     'city': 'Bergen',
#     'postal_code': '5020',
#     'line_1': 'Solheimsgaten 11',
#     'is_hq': False,
#     'state': None},
#    {'country': 'NO',
#     'city': 'Stavanger',
#     'postal_code': '4066',
#     'line_1': 'Maskinveien 26, N-4033 Stavanger',
#     'is_hq': False,
#     'state': None},
#    {'country': 'CA',
#     'city': 'Calgary',
#     'postal_code': 'T2P 1N2',
#     'line_1': '225 6th Avenue SW',
#     'is_hq': False,
#     'state': 'Alberta'},
#    {'country': 'CA',
#     'city': 'Edmonton',
#     'postal_code': 'T5J 3G2',
#     'line_1': '300-10020 101A Avenue',
#     'is_hq': False,
#     'state': 'Alberta'},
#    {'country': 'CA',
#     'city': 'Fredericton',
#     'postal_code': 'E3B 9M4',
#     'line_1': '495 Prospect Street',
#     'is_hq': False,
#     'state': 'New Brunswick'},
#    {'country': 'SG',
#     'city': 'Singapore',
#     'postal_code': '179101',
#     'line_1': '#35-00 Raffles City Tower, 250 North Bridge Road',
#     'is_hq': False,
#     'state': None},
#    {'country': 'SG',
#     'city': 'Singapore',
#     'postal_code': '189767',
#     'line_1': '38 Beach Road',
#     'is_hq': False,
#     'state': None},
#    {'country': 'RO',
#     'city': 'Brasov',
#     'postal_code': '500152',
#     'line_1': '5 Turnului Street',
#     'is_hq': False,
#     'state': None},
#    {'country': 'GB',
#     'city': 'Edinburgh',
#     'postal_code': 'EH3 8EX',
#     'line_1': '144 Morrison Street',
#     'is_hq': False,
#     'state': None},
#    {'country': 'GB',
#     'city': 'London',
#     'postal_code': 'EC3M 3BD',
#     'line_1': '30 Fenchurch Street',
#     'is_hq': False,
#     'state': None},
#    {'country': 'GB',
#     'city': 'Manchester',
#     'postal_code': 'M1 7ED',
#     'line_1': 'Oxford House Second Floor',
#     'is_hq': False,
#     'state': None},
#    {'country': 'GR',
#     'city': 'Athens',
#     'postal_code': '14564',
#     'line_1': '1, Arcadias Str., Kifissia',
#     'is_hq': False,
#     'state': None},
#    {'country': 'FR',
#     'city': 'Sophia Antipolis',
#     'postal_code': '6410',
#     'line_1': '400 Avenue De Roumanille - Bt 1A',
#     'is_hq': False,
#     'state': 'Biot'},
#    {'country': 'TR',
#     'city': 'Istanbul',
#     'postal_code': '34906',
#     'line_1': 'Teknopark İstanbul, Sanayi Mah. Teknopark Bulvarı D Blok No:1/5A İç Kapı No: 201 TR Pendik',
#     'is_hq': False,
#     'state': None},
#    {'country': 'AU',
#     'city': 'Brisbane',
#     'postal_code': '4000',
#     'line_1': 'Level 30, 10 Eagle Street',
#     'is_hq': False,
#     'state': 'Queensland'},
#    {'country': 'AU',
#     'city': 'Kingston',
#     'postal_code': '2604',
#     'line_1': '1/55 Wentworth Avenue',
#     'is_hq': False,
#     'state': 'Australian Capital Territory'},
#    {'country': 'AU',
#     'city': 'Melbourne',
#     'postal_code': '3000',
#     'line_1': 'Level 5/161 Collins Street',
#     'is_hq': False,
#     'state': 'Victoria'},
#    {'country': 'AU',
#     'city': 'Perth',
#     'postal_code': '6000',
#     'line_1': 'Level 34, Exchange Tower',
#     'is_hq': False,
#     'state': 'Western Australia'},
#    {'country': 'AU',
#     'city': 'Barangaroo',
#     'postal_code': '2000',
#     'line_1': 'Level 6, International House',
#     'is_hq': False,
#     'state': 'New South Wales'},
#    {'country': 'SA',
#     'city': 'Al Khobar',
#     'postal_code': '31952',
#     'line_1': 'Al Khobar Gate Tower, 4th Floor',
#     'is_hq': False,
#     'state': None},
#    {'country': 'AR',
#     'city': 'Rosario',
#     'postal_code': 'S2000ATO',
#     'line_1': 'Santa Fe 1173',
#     'is_hq': False,
#     'state': 'Santa Fe'},
#    {'country': 'BE',
#     'city': 'Brussels',
#     'postal_code': '1000',
#     'line_1': 'Picardstraat 11 Rue Picard',
#     'is_hq': False,
#     'state': None},
#    {'country': 'BR',
#     'city': 'Barueri',
#     'postal_code': '06473-900',
#     'line_1': 'Av. Andromeda, 2.000 - Bloco 11, Térreo',
#     'is_hq': False,
#     'state': 'São Paulo'},
#    {'country': 'HK',
#     'city': 'Quarry Bay, Hong Kong',
#     'postal_code': None,
#     'line_1': 'Suites 2/F, 3/F&41/F 4103-10 One Island East',
#     'is_hq': False,
#     'state': 'Hong Kong'},
#    {'country': 'HU',
#     'city': 'Budapest',
#     'postal_code': '1138',
#     'line_1': '1 Bence Street Váci Greens Business Center, B Building',
#     'is_hq': False,
#     'state': None}],
#   'name': 'Accenture',
#   'tagline': None,
#   'universal_name_id': 'accenture',
#   'profile_pic_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/company/accenture/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20240509%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20240509T062342Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=6ee2ca7a27347ff3a317cad2badf4fb37e8affbfa23bed5c7e6c9f65915577ab',
#   'background_cover_image_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/company/accenture/cover?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20240509%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20240509T062342Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=f4cf225aa720b3ed86c41be863c1d4e0020b1a02249cd87a54a18def186b95dc',
#   'search_id': '1033',
#   'similar_companies': [{'name': 'Accenture in South Africa',
#     'link': 'https://www.linkedin.com/company/accenture-in-south-africa',
#     'industry': 'Business Consulting and Services',
#     'location': None},
#    {'name': 'Blue Horseshoe, Part of Accenture',
#     'link': 'https://www.linkedin.com/company/blue-horseshoe',
#     'industry': 'Transportation, Logistics, Supply Chain and Storage',
#     'location': None},
#    {'name': 'Accenture Argentina',
#     'link': 'https://www.linkedin.com/company/accenturear',
#     'industry': 'Business Consulting and Services',
#     'location': None},
#    {'name': 'Accenture Song',
#     'link': 'https://www.linkedin.com/company/accenture-song',
#     'industry': 'Advertising Services',
#     'location': None},
#    {'name': 'Accenture Colombia',
#     'link': 'https://www.linkedin.com/company/accenture-colombia',
#     'industry': 'Business Consulting and Services',
#     'location': None},
#    {'name': 'Accenture Japan',
#     'link': 'https://www.linkedin.com/company/accenture-japan',
#     'industry': 'Business Consulting and Services',
#     'location': None},
#    {'name': 'Accenture in the Philippines',
#     'link': 'https://www.linkedin.com/company/accenture_in_the_philippines',
#     'industry': 'IT Services and IT Consulting',
#     'location': None},
#    {'name': 'Accenture Baltics',
#     'link': 'https://www.linkedin.com/company/accenture-baltics',
#     'industry': 'IT Services and IT Consulting',
#     'location': None},
#    {'name': 'Accenture Brasil',
#     'link': 'https://www.linkedin.com/company/accenturebrasil',
#     'industry': 'IT Services and IT Consulting',
#     'location': None},
#    {'name': 'Accenture Enkitec Group',
#     'link': 'https://www.linkedin.com/company/enkitec',
#     'industry': 'IT Services and IT Consulting',
#     'location': None}],
#   'affiliated_companies': [{'name': 'Accenture Enkitec Group',
#     'link': 'https://www.linkedin.com/company/enkitec/',
#     'industry': 'Information Technology & Services',
#     'location': None},
#    {'name': 'Accenture Brasil',
#     'link': 'https://www.linkedin.com/company/accenturebrasil/',
#     'industry': 'Information Technology & Services',
#     'location': None},
#    {'name': 'Blue Horseshoe, Part of Accenture',
#     'link': 'https://www.linkedin.com/company/blue-horseshoe/',
#     'industry': 'Logistics & Supply Chain',
#     'location': None},
#    {'name': 'Accenture Japan',
#     'link': 'https://www.linkedin.com/company/accenture-japan/',
#     'industry': 'Management Consulting',
#     'location': None},
#    {'name': 'Accenture Baltics',
#     'link': 'https://www.linkedin.com/company/accenture-baltics/',
#     'industry': 'Information Technology & Services',
#     'location': None},
#    {'name': 'Accenture in the Philippines',
#     'link': 'https://www.linkedin.com/company/accenture_in_the_philippines/',
#     'industry': 'Information Technology & Services',
#     'location': None},
#    {'name': 'Accenture in South Africa',
#     'link': 'https://www.linkedin.com/company/accenture-in-south-africa/',
#     'industry': 'Management Consulting',
#     'location': None},
#    {'name': 'Accenture Song',
#     'link': 'https://www.linkedin.com/company/accenture-song/',
#     'industry': 'Marketing & Advertising',
#     'location': None},
#    {'name': 'Accenture Argentina',
#     'link': 'https://www.linkedin.com/company/accenturear/',
#     'industry': 'Management Consulting',
#     'location': None},
#    {'name': 'Accenture Colombia',
#     'link': 'https://www.linkedin.com/company/accenture-colombia/',
#     'industry': 'Management Consulting',
#     'location': None},
#    {'name': 'Accenture Security',
#     'link': 'https://www.linkedin.com/showcase/accenture_security/',
#     'industry': 'Information Technology & Services',
#     'location': None},
#    {'name': 'Accenture The Dock',
#     'link': 'https://www.linkedin.com/showcase/accenture-the-dock/',
#     'industry': 'Information Technology & Services',
#     'location': None},
#    {'name': 'Accenture DACH',
#     'link': 'https://www.linkedin.com/company/accenture-dach/',
#     'industry': 'Information Technology & Services',
#     'location': None},
#    {'name': 'Accenture Israel',
#     'link': 'https://www.linkedin.com/company/accenture_israel/',
#     'industry': 'Information Technology & Services',
#     'location': None},
#    {'name': 'Accenture in India',
#     'link': 'https://www.linkedin.com/company/accentureindia/',
#     'industry': 'Information Technology & Services',
#     'location': 'Bengaluru, Karnatka'},
#    {'name': 'Accenture Baltics',
#     'link': 'https://www.linkedin.com/company/accenture-baltics/',
#     'industry': 'Information Technology & Services',
#     'location': None},
#    {'name': 'Accenture Poland',
#     'link': 'https://www.linkedin.com/company/accenturepoland/',
#     'industry': 'Information Technology & Services',
#     'location': None},
#    {'name': 'Trivadis - Part of Accenture',
#     'link': 'https://www.linkedin.com/company/trivadis-part-of-accenture/',
#     'industry': 'Information Technology & Services',
#     'location': None},
#    {'name': 'Accenture in South Africa',
#     'link': 'https://www.linkedin.com/company/accenture-in-south-africa/',
#     'industry': 'Management Consulting',
#     'location': None},
#    {'name': 'Accenture Nordics',
#     'link': 'https://www.linkedin.com/company/accenture-nordics/',
#     'industry': 'Information Technology & Services',
#     'location': None},
#    {'name': 'Accenture Colombia',
#     'link': 'https://www.linkedin.com/company/accenture-colombia/',
#     'industry': 'Management Consulting',
#     'location': None},
#    {'name': 'Accenture España',
#     'link': 'https://www.linkedin.com/company/accenture-espana/',
#     'industry': 'Management Consulting',
#     'location': None},
#    {'name': 'Accenture Enkitec Group',
#     'link': 'https://www.linkedin.com/company/enkitec/',
#     'industry': 'Information Technology & Services',
#     'location': None},
#    {'name': 'Blue Horseshoe, Part of Accenture',
#     'link': 'https://www.linkedin.com/company/blue-horseshoe/',
#     'industry': 'Logistics & Supply Chain',
#     'location': None},
#    {'name': 'Accenture Bulgaria',
#     'link': 'https://www.linkedin.com/company/accenture_bulgaria/',
#     'industry': 'Information Technology & Services',
#     'location': None},
#    {'name': 'Accenture Middle East',
#     'link': 'https://www.linkedin.com/company/accenture-middle-east/',
#     'industry': 'Management Consulting',
#     'location': None},
#    {'name': 'Accenture Portugal',
#     'link': 'https://www.linkedin.com/company/accenture-portugal/',
#     'industry': 'Information Technology & Services',
#     'location': None},
#    {'name': 'Accenture Belgium',
#     'link': 'https://www.linkedin.com/company/accenture-belgium/',
#     'industry': 'Information Technology & Services',
#     'location': None},
#    {'name': 'Accenture Southeast Asia',
#     'link': 'https://www.linkedin.com/company/accenture-sea/',
#     'industry': 'Management Consulting',
#     'location': None},
#    {'name': 'Accenture the Netherlands',
#     'link': 'https://www.linkedin.com/company/accenture-the-netherlands/',
#     'industry': 'Management Consulting',
#     'location': None},
#    {'name': 'Accenture France',
#     'link': 'https://www.linkedin.com/company/accenture-france/',
#     'industry': 'Information Technology & Services',
#     'location': None},
#    {'name': 'Accenture Italia',
#     'link': 'https://www.linkedin.com/company/accenture-italia/',
#     'industry': 'Information Technology & Services',
#     'location': None},
#    {'name': 'Accenture Australia',
#     'link': 'https://www.linkedin.com/company/accentureaustralia/',
#     'industry': 'Information Technology & Services',
#     'location': None},
#    {'name': 'Accenture UK & Ireland',
#     'link': 'https://www.linkedin.com/company/accenture-uk-ireland/',
#     'industry': 'Information Technology & Services',
#     'location': None},
#    {'name': 'Accenture México',
#     'link': 'https://www.linkedin.com/company/accenture-m-xico/',
#     'industry': 'Management Consulting',
#     'location': None},
#    {'name': 'Accenture na Slovensku ',
#     'link': 'https://www.linkedin.com/company/accenture-na-slovensku/',
#     'industry': 'Information Technology & Services',
#     'location': None},
#    {'name': 'Accenture Argentina',
#     'link': 'https://www.linkedin.com/company/accenturear/',
#     'industry': 'Management Consulting',
#     'location': None},
#    {'name': 'Accenture Hungary',
#     'link': 'https://www.linkedin.com/company/accenture-hungary/',
#     'industry': 'Information Technology & Services',
#     'location': None},
#    {'name': 'Accenture Brasil',
#     'link': 'https://www.linkedin.com/company/accenturebrasil/',
#     'industry': 'Information Technology & Services',
#     'location': None},
#    {'name': 'Accenture in the Philippines',
#     'link': 'https://www.linkedin.com/company/accenture_in_the_philippines/',
#     'industry': 'Information Technology & Services',
#     'location': None},
#    {'name': 'Accenture Federal Services',
#     'link': 'https://www.linkedin.com/company/accenturefederalservices/',
#     'industry': 'Information Technology & Services',
#     'location': None},
#    {'name': 'Accenture Greece',
#     'link': 'https://www.linkedin.com/company/accenture_greece/',
#     'industry': 'Information Technology & Services',
#     'location': None}],
#   'updates': [],
#   'follower_count': 11868334,
#   'acquisitions': None,
#   'exit_data': None,
#   'extra': None,
#   'funding_data': [],
#   'categories': None,
#   'customer_list': None},
#  'last_updated': '2024-04-10T02:24:23Z'}

# %%
response._content
# Out:
# b'{"url": "https://www.linkedin.com/company/accenture", "profile": {"linkedin_internal_id": "1033", "description": "Accenture is a leading global professional services company that helps the world\\u2019s leading businesses, governments and other organizations build their digital core, optimize their operations, accelerate revenue growth and enhance citizen services\\u2014creating tangible value at speed and scale.We are a talent and innovation-led company serving clients in more than 120 countries. Technology is at the core of change today, and we are one of the world\\u2019s leaders in helping drive that change, with strong ecosystem relationships. We combine our strength in technology and leadership in cloud, data and AI with unmatched industry experience, functional expertise and global delivery capability. We are uniquely able to deliver tangible outcomes because of our broad range of services, solutions and assets across Strategy & Consulting, Technology, Operations, Industry X and Song.These capabilities, together with our culture of shared success and commitment to creating 360\\u00b0 value, enable us to help our clients reinvent and build trusted, lasting relationships. We measure our success by the 360\\u00b0 value we create for our clients, each other, our shareholders, partners and communities.", "website": "http://www.accenture.com", "industry": "Business Consulting and Services", "company_size": [10001, null], "company_size_on_linkedin": 574817, "hq": {"country": "IE", "city": "Dublin 2", "postal_code": null, "line_1": "Grand Canal Harbour", "is_hq": true, "state": null}, "company_type": "PUBLIC_COMPANY", "founded_year": null, "specialities": ["Management Consulting", "Systems Integration and Technology", "Business Process Outsourcing", "Application and Infrastructure Outsourcing"], "locations": [{"country": "IE", "city": "Dublin 2", "postal_code": null, "line_1": "Grand Canal Harbour", "is_hq": true, "state": null}, {"country": "US", "city": "San Francisco", "postal_code": "94105", "line_1": "415 Mission Street", "is_hq": false, "state": "California"}, {"country": "FI", "city": "Helsinki", "postal_code": "00180", "line_1": "Porkkalankatu 5", "is_hq": false, "state": "Southern Finland"}, {"country": "MY", "city": "Kuala Lumpur", "postal_code": "55188", "line_1": "Level 29 & 30, Menara Exchange 106", "is_hq": false, "state": "Kuala Lumpur"}, {"country": "PL", "city": "Warsaw", "postal_code": "00-121", "line_1": "Warsaw Towers Sienna 39", "is_hq": false, "state": null}, {"country": "US", "city": "Washington", "postal_code": "20006", "line_1": "800 Connecticut Ave NW", "is_hq": false, "state": "District of Columbia"}, {"country": "NO", "city": "Fornebu", "postal_code": "1326", "line_1": "Rolfsbuktveien 2, 1364", "is_hq": false, "state": null}, {"country": "BR", "city": "Sao Paulo", "postal_code": "04717-004", "line_1": "Rua Alexandre Dumas, 2051", "is_hq": false, "state": "S\\u00e3o Paulo"}, {"country": "IE", "city": "Dublin", "postal_code": "D02 P820", "line_1": "1 Grand Canal Square", "is_hq": false, "state": "Dublin"}, {"country": "BR", "city": "Recife", "postal_code": "50030-230", "line_1": "Edif\\u00edcio Vasco Rodrigues Rua Cais Do Apolo, 222 - 10\\u00ba Andar - Recife", "is_hq": false, "state": "Pernambuco"}, {"country": "IN", "city": "Mumbai", "postal_code": "400708", "line_1": "1st, 2nd, 3rd, & 4th Office Level, Building No. 02", "is_hq": false, "state": "Maharashtra"}, {"country": "US", "city": "Austin", "postal_code": "78701", "line_1": "323 Congress Avenue", "is_hq": false, "state": "Texas"}, {"country": "PH", "city": "Muntinlupa", "postal_code": "1781", "line_1": "Axis Tower One", "is_hq": false, "state": "Metro Manila"}, {"country": "PH", "city": "Cebu City", "postal_code": "6000", "line_1": "W Geonzon St.", "is_hq": false, "state": "Cebu"}, {"country": "PH", "city": "Cebu City", "postal_code": "6000", "line_1": "Don Gil Garcia Street", "is_hq": false, "state": "Cebu"}, {"country": "PH", "city": "Cebu  ...

# %%
import pickle
with open ("linkedin.pkl","wb") as f:
    pickle.dump(response,f)
